# %% [markdown]
# ### 데이터의 시각화
# 1. 사용하는 라이브러리 matplotlib
# 2. 라인, 바, 산점도, 히스토그램 그래프 시각화
# 3. 그 외의 그래프가 여러 종류가 존재

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.xlabel("X")
plt.show()

# %% [markdown]
# - subplot()
#     - 한 영역에 여러개의 그래프를 그려주기위한 함수
#     - subplot(행의 개수, 열의 개수, 위치)

# %%
plt.subplot(1,2,1)
plt.plot([1,2,3,4])
plt.subplot(1,2,2)
plt.plot([4,3,2,1])
plt.show()

# %%
fig, axes = plt.subplots(2,2)
axes[0][0].plot([1,2,3,4])
axes[0][1].plot([4,3,2,1])
axes[1][0].plot([1,2,2,1])
axes[1][1].plot([3,4,2,1])
plt.show()

# %% [markdown]
# - 그래프를 그릴때 주의 할 점
#     - y축의 값만 입력하는 경우 - 문제는 경우가 거의 존재하지 않는다.
#     - x축과 y축의 값을 같이 입력하는 경우
#         - x의 값과 y값의 위치를 정확하게 대입
#         - x의 개수와 y의 개수가 일치

# %%
x = [1,2,3,4]
y = [4,3,2,1]
plt.plot(x, y)
plt.show()

# %%
## x축의 이름 , y축의 이름, 그래프의 이름
plt.plot([1,2,3,4])
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title('title')
plt.show()

# %%
plt.plot([1,2,3,4], label="acending")
plt.plot([4,3,2,1], label="descending")
plt.legend(loc=5)
plt.show()

# %%
## 한글이 깨지는 현상을 막기 위해 폰트 변경
import platform

if platform.system() == "Darwin":   # Mac 인 경우
    plt.rc('font', family='AppleGothic')
else :
    plt.rc('font', family='Malgun Gothic')

# %%
plt.plot([1,2,3,4])
plt.xlabel("x축")
plt.show()

# %%
## Finance-Datareader
# !pip install finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (0.9.34)
# Requirement already satisfied: tqdm in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from finance-datareader) (4.64.0)
# Requirement already satisfied: requests-file in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from finance-datareader) (2.27.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from finance-datareader) (1.4.2)
# Requirement already satisfied: lxml in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from finance-datareader) (4.9.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2022.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.3.0->finance-datareader) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.9)
# Requirement already satisfied: six in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from requests-file->finance-datareader) (1.16.0)
# Requirement already satisfied: colorama in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from tqdm->finance-datareader) (0.4.4)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
kospi = pd.read_excel("kospi.xlsx", index_col='Date')

# %%
# 그래프의 사이즈를 조절
plt.figure(figsize=(14,6))
# grid 추가
plt.grid(True, axis='y')
plt.plot(kospi['Close'].head(20), marker='o')
plt.xlabel("날짜")
plt.ylabel("종가")
plt.show()

# %% [markdown]
# - 바형 그래프
#     - bar() 함수를 이용하여 그래프를 출력
#     - bar(x값, y값)
#     - x값이 존재하지 않으면 에러 발생

# %%
plt.bar([1,2,3,4], [4,3,2,1])
plt.show()

# %%
mean_kospi_2020 = kospi.loc['2020'].resample('MS').mean()
mean_kospi_2020
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-01  2207.549011  2218.407983  2192.596985  2203.442480  2203.442480
# 2020-02-01  2166.166009  2183.180481  2150.528473  2167.123486  2167.123486
# 2020-03-01  1794.281372  1824.905923  1751.699097  1786.746360  1786.746360
# 2020-04-01  1844.271509  1864.863995  1825.824017  1849.588989  1849.588989
# 2020-05-01  1963.487883  1975.821578  1949.949990  1965.174214  1965.174214
# 2020-06-01  2134.890436  2154.157715  2112.594993  2134.696827  2134.696827
# 2020-07-01  2197.626518  2209.355692  2184.291759  2195.948677  2195.948677
# 2020-08-01  2354.817493  2370.443506  2330.037500  2349.873010  2349.873010
# 2020-09-01  2375.035714  2385.536691  2355.750942  2371.516171  2371.516171
# 2020-10-01  2360.252107  2371.771035  2342.014224  2357.821032  2357.821032
# 2020-11-01  2496.544782  2514.414283  2483.233817  2504.180966  2504.180966
# 2020-12-01  2746.468076  2767.551909  2730.494780  2755.770938  2755.770938
#
#                   Volume
# Date
# 2020-01-01  6.547750e+05
# 2020-02-01  6.979300e+05
# 2020-03-01  7.768545e+05
# 2020-04-01  1.052250e+06
# 2020-05-01  8.529158e+05
# 2020-06-01  9.028227e+05
# 2020-07-01  8.202739e+05
# 2020-08-01  8.815750e+05
# 2020-09-01  9.336571e+05
# 2020-10-01  8.259632e+05
# 2020-11-01  1.160714e+06
# 2020-12-01  1.169405e+06

# %%
## x축은 'XXXX년XX월' 표시
mean_kospi_2020.index[0].strftime('%Y년%m월')

x = []
for i in mean_kospi_2020.index:
    x.append(i.strftime("%Y년%m월"))

x
# Out:
# ['2020년01월',
#  '2020년02월',
#  '2020년03월',
#  '2020년04월',
#  '2020년05월',
#  '2020년06월',
#  '2020년07월',
#  '2020년08월',
#  '2020년09월',
#  '2020년10월',
#  '2020년11월',
#  '2020년12월']

# %%
x = mean_kospi_2020.index.strftime("%Y년%m월")

# %%
plt.barh(x, mean_kospi_2020['Volume'])
# 지수 표현식은 일반 표현식으로 변경
plt.ticklabel_format(axis='x', style='plain')
plt.show()

# %% [markdown]
# - 히스토그램
#     - 데이터의 개수를 표현하는 바 그래프

# %%
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
plt.hist(data, bins = 2)
plt.show()

# %%
kospi.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-01-02  2050.550049  2053.449951  2004.270020  2010.000000  2010.000000
# 2019-01-03  2011.810059  2014.719971  1991.650024  1993.699951  1993.699951
# 2019-01-04  1992.400024  2011.560059  1984.530029  2010.250000  2010.250000
# 2019-01-07  2034.239990  2048.060059  2030.900024  2037.099976  2037.099976
# 2019-01-08  2038.680054  2042.699951  2023.589966  2025.270020  2025.270020
#
#               Volume
# Date
# 2019-01-02  326400.0
# 2019-01-03  428000.0
# 2019-01-04  409000.0
# 2019-01-07  440200.0
# 2019-01-08  397800.0

# %%
## kospi에서 변동율 파생변수 생성
## 변동률 = (종가-시가)/시가 * 100
kospi["변동률"] = (kospi['Close'] - kospi['Open']) / kospi['Open'] * 100
kospi.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-01-02  2050.550049  2053.449951  2004.270020  2010.000000  2010.000000
# 2019-01-03  2011.810059  2014.719971  1991.650024  1993.699951  1993.699951
# 2019-01-04  1992.400024  2011.560059  1984.530029  2010.250000  2010.250000
# 2019-01-07  2034.239990  2048.060059  2030.900024  2037.099976  2037.099976
# 2019-01-08  2038.680054  2042.699951  2023.589966  2025.270020  2025.270020
#
#               Volume       변동률
# Date
# 2019-01-02  326400.0 -1.977521
# 2019-01-03  428000.0 -0.900190
# 2019-01-04  409000.0  0.895903
# 2019-01-07  440200.0  0.140592
# 2019-01-08  397800.0 -0.657780

# %%
plt.rc("axes", unicode_minus = False)   # 음수를 표시
plt.grid()
plt.hist(kospi["변동률"], bins=20)
plt.show()

# %%
## candlestick
# !pip install mplfinance
# Out:
# Requirement already satisfied: mplfinance in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (0.12.9b7)
# Requirement already satisfied: pandas in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from mplfinance) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from mplfinance) (3.5.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (1.22.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (9.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from pandas->mplfinance) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\moons\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mplfinance as mpf

# %%
mpf.plot(data = kospi.loc['2020-12'], type='candle')

# %%
marketcolor = mpf.make_marketcolors(
    up = 'r', 
    down = 'b', 
    edge = 'inherit', 
    wick = 'inherit'
)

style = mpf.make_mpf_style(
    base_mpf_style = 'starsandstripes', 
    marketcolors = marketcolor, 
    gridaxis = 'both', 
    y_on_right = True
)

mpf.plot(data = kospi.loc['2020-12'], type='candle', style=style)
